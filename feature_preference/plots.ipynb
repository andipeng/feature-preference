# %%
from __future__ import print_function, division, unicode_literals
# %load_ext autoreload
# %autoreload 2
import math
import time
import numpy as np
import os
import copy
import unicodedata
import string
import re
import json

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from tqdm import tqdm

# %%
num_samples = [10, 30, 50, 100, 200, 300, 500]
comp_accuracy = [0.56, 0.56, .60, 0.88, 0.96, 0.88, 1.0]
feature_comp_accuracy = [0.72, 0.88, 0.90, 1.0, 1.0, 1.0, 1.0]

fig, ax = plt.subplots()
ax.plot(num_samples, comp_accuracy, marker='o', label='comparison')
ax.plot(num_samples, feature_comp_accuracy, marker='o', label='feature_comp')
ax.set_xlabel('Number of Comparisons')
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy of Predicted Preference')
ax.legend()
plt.show()

# %%
num_samples = [10, 30, 50, 100, 200, 300, 500, 1000]
comp_prob = [0.009, 0.55, .79, 0.74, 0.86, 0.86, 0.93, 0.99]

plt.plot(num_samples, comp_prob, marker='o', label='comparison')
plt.xlabel('Number of Training Comparisons')
plt.ylabel('Probability')
plt.title('Probability of Ground Truth')
plt.legend()
plt.show()
